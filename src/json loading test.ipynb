# %%
import pandas as pd
import json
import gzip

# %%
with gzip.open('/Users/adm71/Documents/GitHub/Management/Janelia/JaneliaWorkstationAPI/vfb_images_2020_09_11.json.gz') as f:
   current_data = json.load(f)

current_janelia_df=pd.DataFrame(current_data['images'])
current_janelia_df
# Out:
#                       ad       age   alps_release   area    balancer  \
# 0        GMR_58E02_BB_21  Day 6-10  MB Paper 2014  Brain       L/CyO
# 1        GMR_58E02_BB_21  Day 6-10  MB Paper 2014    VNC       L/CyO
# 2        GMR_52G04_BB_04  Day 6-10  MB Paper 2014  Brain  Homozygous
# 3        GMR_52G04_BB_04  Day 6-10  MB Paper 2014  Brain  Homozygous
# 4        GMR_52G04_BB_04  Day 6-10  MB Paper 2014    VNC  Homozygous
# ...                  ...       ...            ...    ...         ...
# 268812  BJD_115F01_BB_21   Day 1-5     DNp13 2020  Brain        TM6B
# 268813  BJD_121B12_BB_21   Day 1-5     DNp13 2020  Brain   CyO; TM6B
# 268814  BJD_121B12_BB_21   Day 1-5     DNp13 2020    VNC   CyO; TM6B
# 268815  BJD_121B12_BB_21   Day 1-5     DNp13 2020    VNC   CyO; TM6B
# 268816  BJD_121B12_BB_21   Day 1-5     DNp13 2020    VNC   CyO; TM6B
#
#                           data_set               dbd  \
# 0          asoy_mb_polarity_case_1   GMR_22E04_AV_01
# ...

# %%
current_janelia_df['doi'].unique()
# Out:
# array(['10.7554/eLife.04577', '10.7554/eLife.43079',
#        '10.7554/eLife.50901', '10.1016/j.neuron.2017.03.010',
#        '10.7554/eLife.21022', '10.1038/nature24626',
#        '10.7554/elife.34272', '10.7554/eLife.34272',
#        '10.1038/s41586-020-2055-9', None, '10.1016/j.neuron.2020.08.006',
#        '10.1101/404277', '10.7554/eLife.08758',
#        '10.1016/j.cell.2017.06.032', '10.1002/cne.24512',
#        '10.7554/eLife.23496', '10.1016/j.cub.2018.07.002',
#        '10.7554/eLife.16135', '10.1101/198648',
#        '10.1016/j.celrep.2012.09.011', '10.1016/j.cub.2020.07.083',
#        '10.1534/genetics.118.300682', '10.1534/genetics.110.119917'],
#       dtype=object)

# %%
with open('/Users/adm71/Documents/GitHub/Management/Janelia/JaneliaWorkstationAPI/archive/2019/JaneliaAPI_vfb_images.json') as f:
   prev_data = json.load(f)
prev_janelia_df=pd.DataFrame(prev_data['images'])
prev_janelia_df
# Out:
#                    ad       age       alps_release   area    balancer  \
# 0     GMR_58E02_BB_21  Day 6-10      MB Paper 2014  Brain       L/CyO
# 1     GMR_58E02_BB_21  Day 6-10      MB Paper 2014    VNC       L/CyO
# 2     GMR_52G04_BB_04  Day 6-10      MB Paper 2014  Brain  Homozygous
# 3     GMR_52G04_BB_04  Day 6-10      MB Paper 2014  Brain  Homozygous
# 4     GMR_52G04_BB_04  Day 6-10      MB Paper 2014    VNC  Homozygous
# ...               ...       ...                ...    ...         ...
# 3785  GMR_38D01_BB_21  Day 6-10  Lateral Horn 2019  Brain        None
# 3786  GMR_54G12_XA_21  Day 6-10  Lateral Horn 2019  Brain        None
# 3787  GMR_20A02_BB_04  Day 6-10  Lateral Horn 2019  Brain         TM3
# 3788  GMR_41C05_BB_21   Day 1-5  Lateral Horn 2019  Brain        None
# 3789  GMR_41C05_BB_21   Day 1-5  Lateral Horn 2019    VNC        None
#
#                    dbd                  doi                        effector  \
# ...

# %%
prev_janelia_df['doi'].unique()
# Out:
# array(['10.7554/eLife.04577', '10.7554/eLife.43079',
#        '10.7554/eLife.21022', '10.1038/nature24626',
#        '10.7554/elife.34272', '10.1016/j.neuron.2017.03.010', None,
#        '10.1101/404277', '10.7554/eLife.08758',
#        '10.1016/j.cell.2017.06.032', '10.1002/cne.24512',
#        '10.7554/eLife.16135'], dtype=object)

# %%
current_janelia_df.iloc[1]
# Out:
# ad                                                        GMR_58E02_BB_21
# age                                                              Day 6-10
# alps_release                                                MB Paper 2014
# area                                                                  VNC
# balancer                                                            L/CyO
# data_set                                          asoy_mb_polarity_case_1
# dbd                                                       GMR_22E04_AV_01
# doi                                                   10.7554/eLife.04577
# effector                                   TLN-V5_myr-FLAG_Syt-HA_23_0037
# gender                                                             Female
# line                                                           GMR_MB042B
# lsmName                                          FLPO_20121114222136467_2
# mounting_protocol                                    DPX Ethanol Mounting
# ...

# %%
prev_janelia_df.iloc[1]
# Out:
# ad                                                        GMR_58E02_BB_21
# age                                                              Day 6-10
# alps_release                                                MB Paper 2014
# area                                                                  VNC
# balancer                                                            L/CyO
# dbd                                                       GMR_22E04_AV_01
# doi                                                   10.7554/eLife.04577
# effector                                   TLN-V5_myr-FLAG_Syt-HA_23_0037
# gender                                                             Female
# line                                                           GMR_MB042B
# lsmName                                          FLPO_20121114222136467_2
# mounting_protocol                                    DPX Ethanol Mounting
# objective                                                             20x
# ...
